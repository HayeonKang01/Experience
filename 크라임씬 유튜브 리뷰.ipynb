# %%
from selenium import webdriver
import time
from openpyxl import Workbook
import pandas as pd
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup

import warnings 
warnings.filterwarnings('ignore')

# %%
wb = Workbook(write_only=True)
ws = wb.create_sheet()

driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get("https://www.youtube.com/watch?v=m47JUXFjVWo")
driver.implicitly_wait(3)

time.sleep(1.5)

driver.execute_script("window.scrollTo(0, 800)")
time.sleep(3)

last_height = driver.execute_script("return document.documentElement.scrollHeight")

while True:
    driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
    time.sleep(1.5)

    new_height = driver.execute_script("return document.documentElement.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

time.sleep(1.5)

buttons = driver.find_elements_by_css_selector("#more-replies > a")

time.sleep(1.5)

for button in buttons:
    button.send_keys(Keys.ENTER)
    time.sleep(1.5)
    button.click()
    
html_source = driver.page_source
soup = BeautifulSoup(html_source, 'html.parser')

id_list = soup.select("div#header-author > h3 > #author-text > span")
comment_list = soup.select("yt-formatted-string#content-text")

id_final = []
comment_final = []

for i in range(len(comment_list)):
    temp_id = id_list[i].text
    temp_id = temp_id.replace('\n', '')
    temp_id = temp_id.replace('\t', '')
    temp_id = temp_id.replace('    ', '')
    id_final.append(temp_id) # 댓글 작성자

    temp_comment = comment_list[i].text
    temp_comment = temp_comment.replace('\n', '')
    temp_comment = temp_comment.replace('\t', '')
    temp_comment = temp_comment.replace('    ', '')
    comment_final.append(temp_comment) # 댓글 내용
    
pd_data = {"아이디" : id_final , "댓글 내용" : comment_final}
youtube_pd = pd.DataFrame(pd_data)

youtube_pd.to_excel('2-12-2.xlsx')
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 112.0.5615
# Get LATEST chromedriver version for 112.0.5615 google-chrome
# Driver [/Users/hayeon/.wdm/drivers/chromedriver/mac64/112.0.5615.49/chromedriver] found in cache

# %%
df1.to_csv('/Users/hayeon/Downloads/게임 데이터 분석/크라임씬 유튜브/2-0-2.csv', index=False)
df2.to_csv('/Users/hayeon/Downloads/게임 데이터 분석/크라임씬 유튜브/2-1-1.csv', index=False)
df3.to_csv('/Users/hayeon/Downloads/게임 데이터 분석/크라임씬 유튜브/2-2-1.csv', index=False)
df4.to_csv('/Users/hayeon/Downloads/게임 데이터 분석/크라임씬 유튜브/2-3-1.csv', index=False)
df5.to_csv('/Users/hayeon/Downloads/게임 데이터 분석/크라임씬 유튜브/2-4-1.csv', index=False)
df6.to_csv('/Users/hayeon/Downloads/게임 데이터 분석/크라임씬 유튜브/2-5-1.csv', index=False)
df7.to_csv('/Users/hayeon/Downloads/게임 데이터 분석/크라임씬 유튜브/2-6-1.csv', index=False)
df8.to_csv('/Users/hayeon/Downloads/게임 데이터 분석/크라임씬 유튜브/2-7-2.csv', index=False)
df9.to_csv('/Users/hayeon/Downloads/게임 데이터 분석/크라임씬 유튜브/2-8-1.csv', index=False)
df10.to_csv('/Users/hayeon/Downloads/게임 데이터 분석/크라임씬 유튜브/2-9-1.csv', index=False)
df11.to_csv('/Users/hayeon/Downloads/게임 데이터 분석/크라임씬 유튜브/2-10-1.csv', index=False)
df12.to_csv('/Users/hayeon/Downloads/게임 데이터 분석/크라임씬 유튜브/2-11-1.csv', index=False)
df13.to_csv('/Users/hayeon/Downloads/게임 데이터 분석/크라임씬 유튜브/2-12-2.csv', index=False)

# %%
df1 = pd.read_csv('/Users/hayeon/Downloads/게임 데이터 분석/크라임씬 유튜브/2-0-2.csv')
df2 = pd.read_csv('/Users/hayeon/Downloads/게임 데이터 분석/크라임씬 유튜브/2-1-1.csv')
df3 = pd.read_csv('/Users/hayeon/Downloads/게임 데이터 분석/크라임씬 유튜브/2-2-1.csv')
df4 = pd.read_csv('/Users/hayeon/Downloads/게임 데이터 분석/크라임씬 유튜브/2-3-1.csv')
df5 = pd.read_csv('/Users/hayeon/Downloads/게임 데이터 분석/크라임씬 유튜브/2-4-1.csv')
df6 = pd.read_csv('/Users/hayeon/Downloads/게임 데이터 분석/크라임씬 유튜브/2-5-1.csv')
df7 = pd.read_csv('/Users/hayeon/Downloads/게임 데이터 분석/크라임씬 유튜브/2-6-1.csv')
df8 = pd.read_csv('/Users/hayeon/Downloads/게임 데이터 분석/크라임씬 유튜브/2-7-2.csv')
df9 = pd.read_csv('/Users/hayeon/Downloads/게임 데이터 분석/크라임씬 유튜브/2-8-1.csv')
df10 = pd.read_csv('/Users/hayeon/Downloads/게임 데이터 분석/크라임씬 유튜브/2-9-1.csv')
df11 = pd.read_csv('/Users/hayeon/Downloads/게임 데이터 분석/크라임씬 유튜브/2-10-1.csv')
df12 = pd.read_csv('/Users/hayeon/Downloads/게임 데이터 분석/크라임씬 유튜브/2-11-1.csv')
df13 = pd.read_csv('/Users/hayeon/Downloads/게임 데이터 분석/크라임씬 유튜브/2-12-2.csv')

# %%
season2 = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13])

# %%
season2.to_csv('crimescene2.csv', encoding='utf-8')

# %%
season2
# Out:
#           id                                             review  ep
# 0         화리    2멤버들 4에 데려가주세요 ㅠㅠㅠㅠㅠ 진짜 2가 제일 재밌음 스토리 다 외웠어 ㅠㅜㅜ   0
# 1          Y  제발 크라임씬 시즌 4 해조요 ㅠㅠㅠㅠㅠ박지윤 안희연 김지훈 장진 홍진호 데리고 와...   0
# 2        루나루  제발 이멤버 그대로 + 김지훈씨해서 시즌4 해주세요 제발 ㅜㅜㅜ장콩 중 하나라도 빼...   0
# 3         놋냥  10:42 비명지를 정도로 놀라는 와중에도 대답 착실하게 하는거 진짜 ㅋㅋㅋㅋ 너무...   0
# 4        아니,          박지윤씨 씩씩하게 걸어오는 거 너무 귀여우시다ㅠㅠ 표정까지 퍼펙트ㅋㅋㅋㅋㅋ   0
# ..       ...                                                ...  ..
# 184      브리빈                                              23:05  12
# 185    세젤귀또미                                              23:06  12
# 186      아 윤                                                91화  12
# 187       예슬                                              23:05  12
# 188       정볼                                              23:05  12
#
# [3834 rows x 3 columns]

# %% [markdown]
# ---

# %%
import warnings
warnings.filterwarnings(action='ignore')

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import re

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from konlpy.tag import Okt
from collections import Counter

# %%
from konlpy.tag import Kkma, Komoran, Twitter, Hannanum, Mecab

# %%
df = season2

# %%
df.columns = ['id', 'review', 'ep']

# %%
df.fillna("", inplace=True)

# %%
df13.columns = ['id', 'review', 'ep']

# %%
df2.fillna("", inplace=True)

# %%
word_list = []
word_list = df['review'] # 데이터 지정

# %%
okt = Twitter()

# %%
sentences_tag = []
for sentences in word_list:
    morph = okt.pos(sentences)
    sentences_tag.append(morph)

# %%
sentences_tag
# Out:
# [[('2', 'Number'),
#   ('멤버', 'Noun'),
#   ('들', 'Suffix'),
#   ('4', 'Number'),
#   ('에', 'Josa'),
#   ('데려가주세요', 'Verb'),
#   ('ㅠㅠㅠㅠㅠ', 'KoreanParticle'),
#   ('진짜', 'Noun'),
#   ('2', 'Number'),
#   ('가', 'Verb'),
#   ('제일', 'Noun'),
#   ('재밌음', 'Adjective'),
#   ('스토리', 'Noun'),
#   ('다', 'Adverb'),
#   ('외웠어', 'Verb'),
#   ('ㅠㅜㅜ', 'KoreanParticle')],
#  [('제발', 'Noun'),
#   ('크라임씬', 'Noun'),
#   ('시즌', 'Noun'),
#   ('4', 'Number'),
#   ('해조', 'Noun'),
#   ('요', 'Josa'),
#   ('ㅠㅠㅠㅠㅠ', 'KoreanParticle'),
#   ('박지윤', 'Noun'),
#   ('안', 'VerbPrefix'),
#   ('희', 'Adjective'),
#   ('연', 'Noun'),
#   ('김지훈', 'Noun'),
#   ('장진', 'Noun'),
#   ('홍진호', 'Noun'),
#   ('데리', 'Noun'),
#   ('고', 'Josa'),
#   ('와여', 'Verb'),
#   ('ㅠㅠㅠㅠㅠㅠㅠㅠㅠ', 'KoreanParticle'),
#   ('맨날', 'Adverb'),
#   ('시즌', 'Noun'),
#   ('123', 'Number'),
#   ('돌려', 'Verb'),
#   ('보느라', 'Verb'),
#   ('대사', 'Noun'),
#   ('까지', 'Josa'),
#   ('다', 'Adverb'),
#   ('외우게', 'Verb'),
#   ('생겼음', 'Verb'),
# ...

# %%
noun_list = []
for sentences in sentences_tag:
    for word, tag in sentences:
        if tag in ['Noun']:
            noun_list.append(word)

# %%
noun_list
# Out:
# ['멤버',
#  '진짜',
#  '제일',
#  '스토리',
#  '제발',
#  '크라임씬',
#  '시즌',
#  '해조',
#  '박지윤',
#  '연',
#  '김지훈',
#  '장진',
#  '홍진호',
#  '데리',
#  '시즌',
#  '대사',
#  '제발',
#  '멤버',
#  '그대로',
#  '김지훈',
#  '시즌',
#  '제발',
#  '장콩',
#  '중',
#  '하나',
#  '안대',
#  '영',
#  '둘',
#  '무조건',
#  '패키지',
#  '임',
#  '죽',
#  '때',
#  '비명',
#  '정도',
#  '와중',
#  '대답',
#  '진짜',
#  '성실',
#  '와중',
#  '기도',
#  '하니',
#  '꼭',
#  '박지윤',
#  '거',
#  '표정',
#  '퍼펙트',
#  '박지윤',
#  '추리',
#  '이유',
#  '그냥',
#  '감',
#  '와우',
#  '제발',
#  '멤버',
#  '리멤버',
#  '진짜',
#  '시즌',
#  '멤버',
#  '제일',
#  '케미',
#  '추리',
#  '멤버',
#  '그대로',
#  '게스트',
#  '방식',
#  '것',
#  '제작',
#  '진',
#  '여러분',
#  '멤버',
#  '케미',
#  '하니',
#  '첫날',
#  '긴장',
#  '거',
#  '갈수록',
#  '멤버',
#  '거',
#  '모',
#  '크라임씬',
#  '신인',
#  '배우',
#  '이나',
#  '연극배우',
#  '서로',
#  '삽',
#  '외해',
#  '사',
#  '아예',
#  '처음',
#  '역할',
#  '연기',
#  '추리',
#  '먄',
#  '진짜',
#  '크라임씬',
#  '때',
#  '제발',
#  '시즌',
#  '저',
#  '진짜',
#  '크라임씬',
#  '하나',
#  '왓챠',
#  '가입',
#  '밥',
#  '때',
#  '봅니닼',
#  '작가',
# ...

# %%
noun_list = [n for n in noun_list if len(n)>1]
noun_list[:100]
# Out:
# ['멤버',
#  '진짜',
#  '제일',
#  '스토리',
#  '제발',
#  '크라임씬',
#  '시즌',
#  '해조',
#  '박지윤',
#  '김지훈',
#  '장진',
#  '홍진호',
#  '데리',
#  '시즌',
#  '대사',
#  '제발',
#  '멤버',
#  '그대로',
#  '김지훈',
#  '시즌',
#  '제발',
#  '장콩',
#  '하나',
#  '안대',
#  '무조건',
#  '패키지',
#  '비명',
#  '정도',
#  '와중',
#  '대답',
#  '진짜',
#  '성실',
#  '와중',
#  '기도',
#  '하니',
#  '박지윤',
#  '표정',
#  '퍼펙트',
#  '박지윤',
#  '추리',
#  '이유',
#  '그냥',
#  '와우',
#  '제발',
#  '멤버',
#  '리멤버',
#  '진짜',
#  '시즌',
#  '멤버',
#  '제일',
#  '케미',
#  '추리',
#  '멤버',
#  '그대로',
#  '게스트',
#  '방식',
#  '제작',
#  '여러분',
#  '멤버',
#  '케미',
#  '하니',
#  '첫날',
#  '긴장',
#  '갈수록',
#  '멤버',
#  '크라임씬',
#  '신인',
#  '배우',
#  '이나',
#  '연극배우',
#  '서로',
#  '외해',
#  '아예',
#  '처음',
#  '역할',
#  '연기',
#  '추리',
#  '진짜',
#  '크라임씬',
#  '제발',
#  '시즌',
#  '진짜',
#  '크라임씬',
#  '하나',
#  '왓챠',
#  '가입',
#  '봅니닼',
#  '작가',
#  '피디',
#  '깨나',
#  '고생',
#  '명성',
#  '정탐',
#  '탈출',
#  '등등',
#  '장콩',
#  '하니',
#  '지윤',
#  '감독',
#  '지훈']

# %%
counts = Counter(noun_list)
tags = counts.most_common(50)
tags
# Out:
# [('범인', 1072),
#  ('시우민', 983),
#  ('시즌', 774),
#  ('크라임씬', 515),
#  ('진짜', 507),
#  ('하니', 280),
#  ('박지윤', 228),
#  ('제발', 208),
#  ('레전드', 202),
#  ('멤버', 201),
#  ('장진', 201),
#  ('장동민', 155),
#  ('김지훈', 139),
#  ('홍진호', 139),
#  ('사람', 137),
#  ('다시', 130),
#  ('보고', 117),
#  ('추리', 113),
#  ('연기', 109),
#  ('감독', 106),
#  ('탐정', 101),
#  ('사건', 91),
#  ('주행', 84),
#  ('전현무', 84),
#  ('제일', 75),
#  ('이름', 72),
#  ('장성규', 72),
#  ('예능', 69),
#  ('처음', 67),
#  ('역할', 67),
#  ('여기', 64),
#  ('크씬', 64),
#  ('생각', 59),
#  ('게스트', 57),
#  ('존버', 57),
#  ('캐릭터', 56),
#  ('그냥', 55),
#  ('계속', 54),
#  ('하나', 53),
#  ('지금', 49),
#  ('제작', 46),
#  ('조합', 46),
#  ('최고', 46),
#  ('살인', 46),
#  ('보아', 46),
#  ('언제', 45),
#  ('기억', 45),
#  ('모름', 45),
#  ('다른', 44),
#  ('이제', 44)]

# %%
tags.remove(('크라임씬', 515)) # 단어, 횟수
tags.remove(('크씬', 64))
tags.remove(('여기', 64))
tags.remove(('생각', 59))
tags.remove(('모름', 45))

# %%
tags.remove(('진짜', 507))

# %%
tags.remove(('범인', 1072))

# %%
tags.remove(('제발', 208))

# %%
from wordcloud import WordCloud

wordcloud = WordCloud(font_path = '/Users/hayeon/Downloads/Gyeonggi_font_OTF_TTF_0602(Mac)/TTF/경기천년바탕_Bold.ttf',
                     background_color='white', width=1000, height=700)
print(dict(tags))
# Out:
# {'시우민': 983, '시즌': 774, '하니': 280, '박지윤': 228, '레전드': 202, '멤버': 201, '장진': 201, '장동민': 155, '김지훈': 139, '홍진호': 139, '사람': 137, '다시': 130, '보고': 117, '추리': 113, '연기': 109, '감독': 106, '탐정': 101, '사건': 91, '주행': 84, '전현무': 84, '제일': 75, '이름': 72, '장성규': 72, '예능': 69, '처음': 67, '역할': 67, '게스트': 57, '존버': 57, '캐릭터': 56, '그냥': 55, '계속': 54, '하나': 53, '지금': 49, '제작': 46, '조합': 46, '최고': 46, '살인': 46, '보아': 46, '언제': 45, '기억': 45, '다른': 44, '이제': 44}

# %%
cloud = wordcloud.generate_from_frequencies(dict(tags))
plt.figure(figsize=(10, 8))
plt.axis('off')
plt.imshow(cloud)
plt.show()
